# %% [markdown]
# <a href="https://colab.research.google.com/github/pramodnairx/Jupyter-notebooks/blob/main/AgenticAI-Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U langchain-community langgraph langchain-anthropic tavily-python langgraph-checkpoint-sqlite

# %%
# !pip install langchain

# %%
import getpass
import os

os.environ["TAVILY_API_KEY"] = getpass.getpass("Tavily API Key: ")
# Out:
# Tavily API Key:··········

# %%
from langchain_community.tools.tavily_search import TavilySearchResults

search = TavilySearchResults(max_results=2)
search_results = search.invoke("What is the weather in Melbourne, Australia today?")
print(search_results)

tools = [search]
# Out:
# [{'title': 'Weather in Melbourne', 'url': 'https://www.weatherapi.com/', 'content': "{'location': {'name': 'Melbourne', 'region': 'Victoria', 'country': 'Australia', 'lat': -37.8167, 'lon': 144.9667, 'tz_id': 'Australia/Melbourne', 'localtime_epoch': 1743905436, 'localtime': '2025-04-06 12:10'}, 'current': {'last_updated_epoch': 1743904800, 'last_updated': '2025-04-06 12:00', 'temp_c': 18.4, 'temp_f': 65.1, 'is_day': 1, 'condition': {'text': 'Partly cloudy', 'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png', 'code': 1003}, 'wind_mph': 14.8, 'wind_kph': 23.8, 'wind_degree': 280, 'wind_dir': 'W', 'pressure_mb': 1016.0, 'pressure_in': 30.0, 'precip_mm': 0.0, 'precip_in': 0.0, 'humidity': 45, 'cloud': 75, 'feelslike_c': 18.4, 'feelslike_f': 65.1, 'windchill_c': 18.8, 'windchill_f': 65.8, 'heatindex_c': 18.8, 'heatindex_f': 65.8, 'dewpoint_c': 6.0, 'dewpoint_f': 42.8, 'vis_km': 10.0, 'vis_miles': 6.0, 'uv': 4.8, 'gust_mph': 17.0, 'gust_kph': 27.3}}", 'score': 0.9820767}, {'title': 
# ...

# %%
# !pip install -qU "langchain[google-vertexai]"
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.9/98.9 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 2.2 MB/s eta 0:00:00

# %%
from langchain.chat_models import init_chat_model
import vertexai

vertexai.init(project="pn-agenticai-langchain-demo-1")

os.environ["GEMINI_API_KEY"] = getpass.getpass("Gemini API Key: ")

model = init_chat_model("gemini-2.5-pro-exp-03-25", model_provider="google_vertexai")
# Out:
# Gemini API Key: ··········
# None

# %%
from langchain_core.messages import HumanMessage
from langchain_core.output_parsers import StrOutputParser

response = model.invoke(
    [HumanMessage(content="Howdy?")],
    output_parser=StrOutputParser()
)

response.content
# Out:
# ERROR:grpc._plugin_wrapping:AuthMetadataPluginCallback "<google.auth.transport.grpc.AuthMetadataPlugin object at 0x7a757d6f1190>" raised exception!
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/compute_engine/credentials.py", line 126, in refresh
#     self._retrieve_info(request)
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/compute_engine/credentials.py", line 99, in _retrieve_info
#     info = _metadata.get_service_account_info(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/compute_engine/_metadata.py", line 338, in get_service_account_info
#     return get(request, path, params={"recursive": "true"})
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/google/auth/compute_engine/_metadata.py", line 263, in get
#     raise exceptions.TransportError(
# ...
